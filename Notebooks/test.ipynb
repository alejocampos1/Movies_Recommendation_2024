# %%
import pandas as pd

# %%
df_movies = pd.read_parquet("https://github.com/alejocampos1/Henry_PI1_Alejandro-Campos/raw/main/Datasets/Datasets_Limpios/Parquet/movies.parquet")

# %%
df_movies.head()
# Out:
#       id                        title           genres  \
# 0    862                    Toy Story  [16, 35, 10751]
# 1   8844                      Jumanji  [12, 14, 10751]
# 2  15602             Grumpier Old Men      [10749, 35]
# 3  31357            Waiting to Exhale  [35, 18, 10749]
# 4  11862  Father of the Bride Part II             [35]
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                              tagline  runtime release_date  \
# 0                                               None     81.0   1995-10-30
# 1          Roll the dice and unleash the excitement!    104.0   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...    101.0   1995-12-22
# 3  Friends are the people who let you be yourself...    127.0   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...    106.0   1995-02-10
#
#   production_companies  belongs_to_collection original_language  \
# 0                  [3]                  10194                en
# 1   [559, 2550, 10201]                   <NA>                en
# 2        [6194, 19464]                 119050                en
# 3                [306]                   <NA>                en
# 4         [5842, 9195]                  96871                en
#
#   spoken_languages      budget      revenue    status production_countries  \
# 0             [en]  30000000.0  373554033.0  Released            [No Data]
# 1         [en, fr]  65000000.0  262797249.0  Released            [No Data]
# 2             [en]         0.0          0.0  Released            [No Data]
# 3             [en]  16000000.0   81452156.0  Released            [No Data]
# 4             [en]         0.0   76578911.0  Released            [No Data]
#
#    popularity  vote_average  vote_count  release_year     return
# 0   21.946943           7.7      5415.0          1995  12.451801
# 1   17.015539           6.9      2413.0          1995   4.043035
# 2   11.712900           6.5        92.0          1995   0.000000
# 3    3.859495           6.1        34.0          1995   5.090760
# 4    8.387519           5.7       173.0          1995   0.000000
